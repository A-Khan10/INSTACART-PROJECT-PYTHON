# %%
# Task 4.7: Deriving New Variables

## Step 1 - Following the Exercise.

# %% [markdown]
# ### 01. Importing Libraries

# %%
# Importing libraries.
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 02. Importing Dataframe

# %%
# Defining the path
path = r'/Users/Ayaz/Desktop/Instacart Basket Analysis'

# %%
# Importing "ords_prods_merged" dataframe
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Creating subset of first one million rows.
df = df_ords_prods_merge[:1000000]

# %%
# checking shape 
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# ### 03. If-Statements with User-Defined Functions

# %%
# Defining the "price_label" function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the "price_label" function on dataframe
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/44/7xyg5dc91nb96tdj20w49k0r0000gp/T/ipykernel_9365/3723448627.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Checking max price of products.
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ### 04. If-Statements with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/44/7xyg5dc91nb96tdj20w49k0r0000gp/T/ipykernel_9365/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Checking the value counts
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Applying the process on entire "ords_prods_merge" dataframe.
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'low-range product'

# %%
# Checking the value counts 
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### 05. If-Statements with For-Loops

# %%
# Checking the value counts
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Creating a new column for 'orders_day_of_week'
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# ## Step 2 - New Column for Busiest & Slowest days.

# %%
# Checking the frequncy of the orders_days_of_week column.
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# New Column and Lables for "orders_day_of_week" column.  
result2 = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value == 1:
    result2.append("Busiest days")
  elif value == 4 or value == 3:
    result2.append("Slowest days")
  else:
    result2.append("Regularly days")

# %%
result2
# Out:
# ['Regularly days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly days',
#  'Regularly days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly days',
#  'Regularly days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly days',
#  'Regularly days',
#  'Busiest days',
#  'Regularly days',
#  'Regularly days',
#  'Busiest days',
#  'Regularly days',
#  'Regularly days',
#  'Regularly days',
#  'Slowest days',
#  'Regularly days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly days',
#  'Regularly days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
# Adding new result to datafarame in new column
df_ords_prods_merge['busiest_days'] = result2

# %% [markdown]
# ## Step 3 - Check the values of new column.

# %%
# Checking the values of new column.
df_ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly days    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest_days, dtype: int64

# %%
# Checking the value of 'orders_days_of_week' column
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# #### The highest frequency values are 0 (Saturday) and 1 (Sunday), meaning Saturday and Sunday are the busiest days. A value of 4 (Wednesday) and 3 (Tuesday) is the slowest day for Instagram app orders.

# %% [markdown]
# ## Step 4 - New Column for Busiest period of day.

# %%
# checking column names
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  new_customer  product_id  add_to_cart_order  \
# 0                    NaN          True         196                  1
# 1                   15.0         False         196                  1
# 2                   21.0         False         196                  1
# 3                   29.0         False         196                  1
# 4                   28.0         False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
# Checking frequncy of the values in the "order_hour_of_day" column
df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# #### "Most orders" hours (10, 11, 14, 15, 13, 12, 16, 9)
# #### "Average orders" hours (17, 8, 18, 19, 20, 7, 21, 22)
# #### "Fewest orders" hours (23, 6, 0, 1, 5, 2, 4, 3)

# %%
# Creatig new column for "order_hour_of_day"
result3 = []

for value in df_ords_prods_merge["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        result3.append("Most orders")
    elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
        result3.append("Average orders")
    else:
        result3.append("Fewest orders")

# %%
# Adding new result to dataframe in new column "busiest_period_of_day"
df_ords_prods_merge['busiest_period_of_day'] = result3

# %%
# checking the outputof new dataframe columns
df_ords_prods_merge[['order_hour_of_day', 'busiest_period_of_day']].head(10)
# Out:
#    order_hour_of_day busiest_period_of_day
# 0                  8        Average orders
# 1                  7        Average orders
# 2                 12           Most orders
# 3                  7        Average orders
# 4                 15           Most orders
# 5                  7        Average orders
# 6                  9           Most orders
# 7                 14           Most orders
# 8                 16           Most orders
# 9                  8        Average orders

# %% [markdown]
# ## Step 5 - Frequncy check for new column

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ## Step 6 & 7 - Checked and Export Data

# %%
# Exporting dataframe in pikcle formate
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))
